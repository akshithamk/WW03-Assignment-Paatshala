# %% [markdown]
# # Do the following operation on Iris dataset:

# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('iris.csv')

# %% [markdown]
# # 2. Display the columns in the dataset

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3.Calculate the mean of each column of the dataset.

# %%
columns =['SL', 'SW', 'PL', 'PW']
data[columns].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4.Check for the null values present in the dataset.

# %%
data.isna().sum()##provides null value for each columns if it has any null values
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
data.isna().sum().sum()## provides the total count of null values in a dataset
# Out:
# 0

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
plt.figure(figsize=(8,8))
plt.hist(data['SL'],color='green',rwidth=0.9)
plt.title('Histogram of Iris dataset',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Histogram of Iris dataset')

# %%
data[['SL','SW']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#scatterplot

# %%
plt.figure(figsize=(8,8))
plt.scatter(data['SL'],data['PL'],s=15,c='red',marker='^')
plt.title('Plot of SL vs PL',fontsize=16)
plt.xlabel('SL')
plt.ylabel('PL')
# Out:
# Text(0, 0.5, 'PL')

# %%
#pair plots

# %%
sns.pairplot(data)

# %%
# Box plot

# %%
plt.boxplot(data['PW'])
plt.title('Box plot of PW')
plt.xlabel('PW')
# Out:
# Text(0.5, 0, 'PW')

# %%
#violin plot

# %%
sns.violinplot(x='PW',y='SW',data=data)
# Out:
# <AxesSubplot:xlabel='PW', ylabel='SW'>
